# %% [markdown]
# # Top Charts Song Classification

# %% [markdown]
# ## Outline
# 1. <a href='#1'>Introduction</a>
# 2. <a href='#2'>Dataset Setup</a>
# 3. <a href='#3'>Results</a>
# 4. <a href='#4'>Discussion</a>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ## 2. Dataset Setup

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from spotipy import Spotify, oauth2
import secret

# %%
def import_data():
    """
    Import all the song data from raw, unedited csv within this folder
    Returns csv as a dataframe object (still uncleaned)
    Link to Dataset on Kaggle: https://www.kaggle.com/datasets/multispiros/34740-hit-and-nonhit-songs-spotify-features?resource=download
    """
    unedited_song_data = pd.read_csv('unedited_song_data.csv')
    return unedited_song_data

# %% [markdown]
# ### Spotify API Setup

# %%
class SpotifyAPI:
    def __init__(self, client_id: str, client_secret: str):
        """
        Create a SpotifyAPI object
        :param client_id: Your Spotify client ID
        :param client_secret: Your Spotify client secret
        """
        credentials_manager = oauth2.SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
        self.sp = Spotify(client_credentials_manager=credentials_manager)
        self.artist_popularity = {}
    
    def add_artist_popularity(artist_popularity_pair: dict):
        artist_popularity.update(artist_popularity_pair)

    def artist_popularity_from_track(self, track_spotify_id: str):
        """
        Returns the popularity of the track's artist
        :param track_spotify_id: Spotify ID of the track
        """
        spotify_track = self.sp.track(track_id=track_spotify_id)
        return spotify_track
#         primary_artist_id = spotify_track
#         print(primary_artist_id)
        
        # return self.sp.artist(primary_artist_id)['popularity']

# %%
spotify_api = SpotifyAPI(client_id=secret.spotify_client_id, client_secret=secret.spotify_secret_key)

# %%
spotify_api

# %%
spotify_api.add_artist_popularity({'sumana': 19})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qt/66m__9rs0nng8lcyvrnt4hf80000gn/T/ipykernel_95616/395360234.py in <module>
# ----> 1 spotify_api.add_artist_popularity({'sumana': 19})
#
# TypeError: add_artist_popularity() takes 1 positional argument but 2 were given

# %% [markdown]
# ### Data Cleaning Methods

# %%
def add_popularity_info(data):
    spotify_api = SpotifyAPI(client_id=secret.spotify_client_id, client_secret=secret.spotify_secret_key)

    data['Artist Popularity'] = data.apply(lambda row: spotify_api.artist_popularity_from_track(row.track_id), axis=1)
    return data

# %%
unedited_song_data = import_data()
test_cleaned_song_data = unedited_song_data.copy().dropna()
# del test_cleaned_song_data['track_title']
# del test_cleaned_song_data['key']
# del test_cleaned_song_data['time_signature']

# cleaned_song_data = add_popularity_info(cleaned_song_data)

# del test_cleaned_song_data['track_id']
len(pd.unique(test_cleaned_song_data.artist_name))
test_cleaned_song_data['artist_name'] = test_cleaned_song_data['artist_name'].str.strip()
test_cleaned_song_data['artist_name'] = test_cleaned_song_data['artist_name'].str.lower()
# dups_removed = test_cleaned_song_data[test_cleaned_song_data.duplicated(['artist_name'])]
dups_removed = test_cleaned_song_data.drop_duplicates(subset=['artist_name'])
dups_removed
# print(test_cleaned_song_data.artist_name.drop_duplicates())
# print(dups_removed.iat[2, 1], dups_removed.iat[1, 1], dups_removed.iat[2, 1] == dups_removed.iat[1, 1])
# Out:
#                                              track_title  \
# 0                          Red Planet - Red Planet Radio
# 2                                               Basejump
# 3      Goldberg Variations, BWV 988 (Arr. for Accordi...
# 67               Piano Concerto No. 1, Op. 15: II. Largo
# 79                                         Llego El Amor
# ...                                                  ...
# 34721                         Friday  - Dopamine Re-Edit
# 34726                                               Fiel
# 34729                                    Chicken Tendies
# 34735                               Además de Mí - Remix
# 34736                                             Drunk
#
#                        artist_name                track_id  duration_ms  \
# 0                              joe  3FeufAV1f6fajILIQuAXMw       256080
# 2                     robin schulz  6nWoNNkfffbmHU9z3kGPao       391680
# 3            johann sebastian bach  5Zg1UOcmee5oiRw3gbXna0       347840
# 67            ludwig van beethoven  3ZD7POEWTQETjyVzigY6mn       699600
# 79          los cadetes de linares  2y2iU8nqJGWpLfBeHbFInM       128484
# ...                            ...                     ...          ...
# 34721                        riton  4cG7HUWYHBV6R6tHn1gxrl       169153
# 34726              los legendarios  7Bk0uXKk1uPT0XuQbpFzvs       261667
# 34729                 clinton kane  0awuNCj9gwJEM0seER22DW       196844
# 34735                   rusherking  7I8L3vYCLThw2FDrE6LuzE       330040
# 34736  elle king & miranda lambert  0QULNNd9z5s35entfiiXoa       245626
#
#         energy  key  mode  time_signature  acousticness  danceability  \
# 0      0.96800    7     0               4       0.02150         0.698
# 2      0.40600    5     0               4       0.00433         0.803
# 3      0.00267    7     0               5       0.91000         0.150
# 67     0.02740    8     1               4       0.96300         0.161
# 79     0.85300    0     1               4       0.22100         0.784
# ...        ...  ...   ...             ...           ...           ...
# 34721  0.86200    2     1               4       0.00760         0.824
# 34726  0.70100    6     0               4       0.40700         0.849
# 34729  0.68900    7     1               4       0.35800         0.570
# 34735  0.61300    6     1               4       0.03960         0.397
# 34736  0.88400    5     1               4       0.00516         0.612
#
#        instrumentalness  liveness  loudness  speechiness  valence    tempo  \
# 0              0.862000    0.1110   -11.012       0.0337   0.3900  136.884
# 2              0.825000    0.0948    -9.444       0.0608   0.0769  125.014
# 3              0.028700    0.1250   -24.701       0.0434   0.1050  135.652
# 67             0.889000    0.1190   -27.520       0.0394   0.0795   79.607
# 79             0.000016    0.0678    -4.089       0.0370   0.9630  116.885
# ...                 ...       ...       ...          ...      ...      ...
# 34721          0.000132    0.3030    -3.424       0.1260   0.8010  122.980
# 34726          0.000000    0.1120    -4.407       0.0600   0.5050   98.005
# 34729          0.000000    0.0819    -6.242       0.1470   0.5680  100.087
# 34735          0.000000    0.1920    -5.077       0.0549   0.4050   78.400
# 34736          0.000000    0.0997    -4.400       0.0459   0.6260  119.991
#
#        On_chart
# 0             0
# 2             0
# 3             0
# 67            0
# 79            0
# ...         ...
# 34721         1
# 34726         1
# 34729         1
# 34735         1
# 34736         1
#
# [10754 rows x 17 columns]

# %%
artist_popularity = {}
for track_id in test_cleaned_song_data.track_id:
    spotify_api = SpotifyAPI(client_id=secret.spotify_client_id, client_secret=secret.spotify_secret_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qt/66m__9rs0nng8lcyvrnt4hf80000gn/T/ipykernel_92961/4141206941.py in <module>
#       1 artist_popularity = {}
#       2 for track_id in test_cleaned_song_data.track_id:
# ----> 3     spotify_api = SpotifyAPI(client_id=secret.spotify_client_id, client_secret=secret.spotify_secret_key)
#       4
#
# NameError: name 'SpotifyAPI' is not defined

# %%
def clean_data(unedited_song_data):
    """
    Cleans the given csv by removing not helpful features from our database and
    replaces the artist_name column with the artist popularity metric from the
    Spotify API
    Returns the cleaned DataFrame
    :param unedited_song_data: the unedited and uncleaned DataFrame object
    """
    cleaned_song_data = unedited_song_data.copy().dropna()
    del cleaned_song_data['track_title']
    del cleaned_song_data['key']
    del cleaned_song_data['time_signature']
    cleaned_song_data['artist_name'] = cleaned_song_data['artist_name'].str.strip()

    cleaned_song_data = add_popularity_info(cleaned_song_data)

    del cleaned_song_data['track_id']

    return cleaned_song_data

# %%
def split_data(cleaned_song_data):
    """
    Splits the training data into a 75%/25% split with the 25% allotted for testing
    Returns the data split into x_train, x_test, y_train and y_test
    :param cleaned_song_data: the cleaned DataFrame object 
    """
    song_y = cleaned_song_data['on_chart']
    song_x = cleaned_song_data.drop(['on_chart'], axis=1)
    x_train, x_test, y_train, y_test = train_test_split(song_x, song_y, test_size=0.25)
    x_train = x_train.reset_index(drop=True)
    x_test = x_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)
    return x_train, x_test, y_train, y_test

# %% [markdown]
# ### Cleaning the Data

# %%
uncleaned_song_data = import_data()

# %%
uncleaned_song_data
# Out:
#                                              track_title  \
# 0                          Red Planet - Red Planet Radio
# 1                       Red Planet - Red Planet Extended
# 2                                               Basejump
# 3      Goldberg Variations, BWV 988 (Arr. for Accordi...
# 4      Goldberg Variations, BWV 988 (Arr. for Accordi...
# ...                                                  ...
# 34735                               Además de Mí - Remix
# 34736                                             Drunk
# 34737                   Breaking Up Was Easy In The 90's
# 34738                                             Nobody
# 34739                                               Gone
#
#                        artist_name                track_id  duration_ms  \
# 0                              Joe  3FeufAV1f6fajILIQuAXMw       256080
# 1                              Joe  2o7oYjZuo3S2QitY4R5dII       395442
# 2                     Robin Schulz  6nWoNNkfffbmHU9z3kGPao       391680
# 3            Johann Sebastian Bach  5Zg1UOcmee5oiRw3gbXna0       347840
# 4            Johann Sebastian Bach  2ZWmWGoZS2OTGZSnMhck7Q       181733
# ...                            ...                     ...          ...
# 34735                   Rusherking  7I8L3vYCLThw2FDrE6LuzE       330040
# 34736  Elle King & Miranda Lambert  0QULNNd9z5s35entfiiXoa       245626
# 34737                     Sam Hunt  4sf2L157iEgAR7yrCNLgSq       215933
# 34738                  Dylan Scott  5TWAIHYaOnYg4txfmCgon5       160707
# 34739               Dierks Bentley  7IhfjcaXuXCq20ZiAA7igK       205960
#
#         energy  key  mode  time_signature  acousticness  danceability  \
# 0      0.96800    7     0               4       0.02150         0.698
# 1      0.97000    2     1               4       0.00339         0.724
# 2      0.40600    5     0               4       0.00433         0.803
# 3      0.00267    7     0               5       0.91000         0.150
# 4      0.22600    7     1               4       0.76800         0.290
# ...        ...  ...   ...             ...           ...           ...
# 34735  0.61300    6     1               4       0.03960         0.397
# 34736  0.88400    5     1               4       0.00516         0.612
# 34737  0.64900    9     1               4       0.23100         0.562
# 34738  0.74700    0     1               4       0.51900         0.573
# 34739  0.74600    6     1               4       0.00985         0.521
#
#        instrumentalness  liveness  loudness  speechiness  valence    tempo  \
# 0              0.862000    0.1110   -11.012       0.0337   0.3900  136.884
# 1              0.896000    0.1060    -8.415       0.0358   0.4320  136.868
# 2              0.825000    0.0948    -9.444       0.0608   0.0769  125.014
# 3              0.028700    0.1250   -24.701       0.0434   0.1050  135.652
# 4              0.000002    0.1050   -14.990       0.0385   0.4700   98.348
# ...                 ...       ...       ...          ...      ...      ...
# 34735          0.000000    0.1920    -5.077       0.0549   0.4050   78.400
# 34736          0.000000    0.0997    -4.400       0.0459   0.6260  119.991
# 34737          0.000000    0.3410    -5.400       0.0494   0.3760  145.913
# 34738          0.000001    0.0867    -6.460       0.0319   0.6450   79.952
# 34739          0.000000    0.0741    -6.173       0.0351   0.4730  149.977
#
#        On_chart
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 34735         1
# 34736         1
# 34737         1
# 34738         1
# 34739         1
#
# [34740 rows x 17 columns]

# %%
uncleaned_song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34740 entries, 0 to 34739
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_title       34739 non-null  object
#  1   artist_name       34739 non-null  object
#  2   track_id          34740 non-null  object
#  3   duration_ms       34740 non-null  int64
#  4   energy            34740 non-null  float64
#  5   key               34740 non-null  int64
#  6   mode              34740 non-null  int64
#  7   time_signature    34740 non-null  int64
#  8   acousticness      34740 non-null  float64
#  9   danceability      34740 non-null  float64
#  10  instrumentalness  34740 non-null  float64
#  11  liveness          34740 non-null  float64
#  12  loudness          34740 non-null  float64
#  13  speechiness       34740 non-null  float64
#  14  valence           34740 non-null  float64
#  15  tempo             34740 non-null  float64
#  16  On_chart          34740 non-null  int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 4.5+ MB

# %%
cleaned_song_data = clean_data(uncleaned_song_data)

# %%
cleaned_song_data
# Out:
#                        artist_name  duration_ms   energy  mode  acousticness  \
# 0                              Joe       256080  0.96800     0       0.02150
# 1                              Joe       395442  0.97000     1       0.00339
# 2                     Robin Schulz       391680  0.40600     0       0.00433
# 3            Johann Sebastian Bach       347840  0.00267     0       0.91000
# 4            Johann Sebastian Bach       181733  0.22600     1       0.76800
# ...                            ...          ...      ...   ...           ...
# 34735                   Rusherking       330040  0.61300     1       0.03960
# 34736  Elle King & Miranda Lambert       245626  0.88400     1       0.00516
# 34737                     Sam Hunt       215933  0.64900     1       0.23100
# 34738                  Dylan Scott       160707  0.74700     1       0.51900
# 34739               Dierks Bentley       205960  0.74600     1       0.00985
#
#        danceability  instrumentalness  liveness  loudness  speechiness  \
# 0             0.698          0.862000    0.1110   -11.012       0.0337
# 1             0.724          0.896000    0.1060    -8.415       0.0358
# 2             0.803          0.825000    0.0948    -9.444       0.0608
# 3             0.150          0.028700    0.1250   -24.701       0.0434
# 4             0.290          0.000002    0.1050   -14.990       0.0385
# ...             ...               ...       ...       ...          ...
# 34735         0.397          0.000000    0.1920    -5.077       0.0549
# 34736         0.612          0.000000    0.0997    -4.400       0.0459
# 34737         0.562          0.000000    0.3410    -5.400       0.0494
# 34738         0.573          0.000001    0.0867    -6.460       0.0319
# 34739         0.521          0.000000    0.0741    -6.173       0.0351
#
#        valence    tempo  On_chart
# 0       0.3900  136.884         0
# 1       0.4320  136.868         0
# 2       0.0769  125.014         0
# 3       0.1050  135.652         0
# 4       0.4700   98.348         0
# ...        ...      ...       ...
# 34735   0.4050   78.400         1
# 34736   0.6260  119.991         1
# 34737   0.3760  145.913         1
# 34738   0.6450   79.952         1
# 34739   0.4730  149.977         1
#
# [34739 rows x 13 columns]

# %%
cleaned_song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34739 entries, 0 to 34739
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       34739 non-null  object
#  1   duration_ms       34739 non-null  int64
#  2   energy            34739 non-null  float64
#  3   mode              34739 non-null  int64
#  4   acousticness      34739 non-null  float64
#  5   danceability      34739 non-null  float64
#  6   instrumentalness  34739 non-null  float64
#  7   liveness          34739 non-null  float64
#  8   loudness          34739 non-null  float64
#  9   speechiness       34739 non-null  float64
#  10  valence           34739 non-null  float64
#  11  tempo             34739 non-null  float64
#  12  On_chart          34739 non-null  int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 3.7+ MB
